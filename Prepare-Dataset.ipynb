# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load dataset

# %%
import pandas as pd

# %%
#import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/My LLM Lab/Dataset/health-food-new-500/health-food-new-500.csv')

# %%
df
# Out:
#                                            instruction input  \
# 0                เขียนแนะนำเกี่ยวกับการดูแลสุขภาพที่ดี   NaN
# 1                                    NCDs ย่อมาจากอะไร   NaN
# 2                                         NCDs คืออะไร   NaN
# 3                       ตัวอย่างของโรค NCDs มีอะไรบ้าง   NaN
# 4        ตัวอย่างโรคทางระบบหัวใจและหลอดเลือดมีอะไรบ้าง   NaN
# ..                                                 ...   ...
# 570   เนื่องจากสังคมสมัยนี้ คนส่วนใหญ่มักฝากท้องไว้...   NaN
# 571   เนื่องจากสังคมสมัยนี้ คนส่วนใหญ่มักฝากท้องไว้...   NaN
# 572   เนื่องจากสังคมสมัยนี้ คนส่วนใหญ่มักฝากท้องไว้...   NaN
# 573   เนื่องจากสังคมสมัยนี้ คนส่วนใหญ่มักฝากท้องไว้...   NaN
# 574                น้ำปลาหรือซีอิ๊ว 1 ช้อนชา มีโซเดียม   NaN
#
#                                                 output
# 0    การดูแลสุขภาพที่ดีมีหลายวิธี เช่น การทานอาหารท...
# 1                            non-communicable diseases
# 2    เป็นกลุ่มโรคไม่ติดต่อเรื้อรัง คือ ไม่ได้เกิดจา...
# ...

# %%
# df = [df1, df2, df3 ,df4]
# pantip = pd.concat(df, ignore_index=True, sort=False)

# %% [markdown]
# # Add Instruction Column

# %%
#df["instruction"] = "แก้คำผิด"

# %%
#df = df.rename(columns={"WRONG":"input", "CORRECT":"output"})

# %%
#df=df[['instruction','input','output']]

# %%
df.to_json("/content/drive/MyDrive/My LLM Lab/Dataset/health-food-new-500/health-food-new-500.jsonl",orient='records', lines=True)

# %%
df.shape      # (xxxx, 3)
# Out:
# (575, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  575 non-null    object
#  1   input        1 non-null      object
#  2   output       575 non-null    object
# dtypes: object(3)
# memory usage: 13.6+ KB

# %% [markdown]
# ## Save df to CSV

# %%
df.to_csv('/content/drive/MyDrive/My LLM Lab/Dataset/health-food-1000.csv', index=False)
